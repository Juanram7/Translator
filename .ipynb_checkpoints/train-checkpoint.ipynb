# %%
# !pip3 install OpenNMT-py
# Out:
# Collecting OpenNMT-py
#   Downloading OpenNMT_py-3.4-py3-none-any.whl (250 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.3.0-cp39-cp39-win_amd64.whl (1.8 MB)
# Collecting torch<2.1,>=1.13
#   Downloading torch-2.0.1-cp39-cp39-win_amd64.whl (172.4 MB)
# Collecting configargparse
#   Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Collecting ctranslate2<4,>=3.2
#   Downloading ctranslate2-3.19.0-cp39-cp39-win_amd64.whl (20.1 MB)
# Collecting fasttext-wheel
#   Downloading fasttext_wheel-0.9.2-cp39-cp39-win_amd64.whl (225 kB)
# Requirement already satisfied: pyyaml in c:\users\juan\anaconda3\lib\site-packages (from OpenNMT-py) (6.0)
# Collecting pyahocorasick
#   Downloading pyahocorasick-2.0.0-cp39-cp39-win_amd64.whl (39 kB)
# Collecting waitress
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
# Collecting sacrebleu
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
# Requirement already satisfied: flask in c:\users\juan\anaconda3\lib\site-packages (from OpenNMT-py) (1.1.2)
# Collecting tensorboard>=2.3
#   Downloading tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
# Collecting pyonmttok<2,>=1.35
#   Downloading pyonmttok-1.37.1-cp39-cp39-win_amd64.whl (14.4 MB)
# Collecting spacy
#   Downloading spacy-3.6.1-cp39-cp39-win_amd64.whl (12.1 MB)
# Requirement already satisfied: numpy in c:\users\juan\anaconda3\lib\site-packages (from ctranslate2<4,>=3.2->OpenNMT-py) (1.21.5)
# Collecting protobuf>=3.19.6
#   Downloading protobuf-4.24.3-cp39-cp39-win_amd64.whl (430 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\juan\anaconda3\lib\site-packages (from tensorboard>=2.3->OpenNMT-py) (2.27.1)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\juan\anaconda3\lib\site-packages (from tensorboard>=2.3->OpenNMT-py) (3.3.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\juan\anaconda3\lib\site-packages (from tensorboard>=2.3->OpenNMT-py) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\juan\anaconda3\lib\site-packages (from tensorboard>=2.3->OpenNMT-py) (2.0.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\juan\anaconda3\lib\site-packages (from tensorboard>=2.3->OpenNMT-py) (1.33.0)
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.58.0-cp39-cp39-win_amd64.whl (4.3 MB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\juan\anaconda3\lib\site-packages (from tensorboard>=2.3->OpenNMT-py) (61.2.0)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\juan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\juan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\juan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\juan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.2.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.23.0-py2.py3-none-any.whl (181 kB)
# Requirement already satisfied: urllib3<2.0 in c:\users\juan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (1.26.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\juan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\juan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\juan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (3.3)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: jinja2 in c:\users\juan\anaconda3\lib\site-packages (from torch<2.1,>=1.13->OpenNMT-py) (2.11.3)
# Requirement already satisfied: sympy in c:\users\juan\anaconda3\lib\site-packages (from torch<2.1,>=1.13->OpenNMT-py) (1.10.1)
# Requirement already satisfied: filelock in c:\users\juan\anaconda3\lib\site-packages (from torch<2.1,>=1.13->OpenNMT-py) (3.6.0)
# Requirement already satisfied: typing-extensions in c:\users\juan\anaconda3\lib\site-packages (from torch<2.1,>=1.13->OpenNMT-py) (4.1.1)
# Requirement already satisfied: networkx in c:\users\juan\anaconda3\lib\site-packages (from torch<2.1,>=1.13->OpenNMT-py) (2.7.1)
# Collecting pybind11>=2.2
#   Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: click>=5.1 in c:\users\juan\anaconda3\lib\site-packages (from flask->OpenNMT-py) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\juan\anaconda3\lib\site-packages (from flask->OpenNMT-py) (2.0.1)
# Requirement already satisfied: colorama in c:\users\juan\anaconda3\lib\site-packages (from click>=5.1->flask->OpenNMT-py) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\juan\anaconda3\lib\site-packages (from jinja2->torch<2.1,>=1.13->OpenNMT-py) (2.0.1)
# Requirement already satisfied: regex in c:\users\juan\anaconda3\lib\site-packages (from sacrebleu->OpenNMT-py) (2022.3.15)
# Requirement already satisfied: lxml in c:\users\juan\anaconda3\lib\site-packages (from sacrebleu->OpenNMT-py) (4.8.0)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\juan\anaconda3\lib\site-packages (from sacrebleu->OpenNMT-py) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\juan\anaconda3\lib\site-packages (from portalocker->sacrebleu->OpenNMT-py) (302)
# Requirement already satisfied: packaging>=20.0 in c:\users\juan\anaconda3\lib\site-packages (from spacy->OpenNMT-py) (21.3)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp39-cp39-win_amd64.whl (25 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-win_amd64.whl (122 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\juan\anaconda3\lib\site-packages (from spacy->OpenNMT-py) (4.64.0)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.3.0-py3-none-any.whl (374 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp39-cp39-win_amd64.whl (39 kB)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.12-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.7-cp39-cp39-win_amd64.whl (483 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.9-py3-none-any.whl (17 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\juan\anaconda3\lib\site-packages (from packaging>=20.0->spacy->OpenNMT-py) (3.0.4)
# Collecting pydantic-core==2.6.3
#   Downloading pydantic_core-2.6.3-cp39-none-win_amd64.whl (1.7 MB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.10-cp39-cp39-win_amd64.whl (7.4 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.3-py3-none-any.whl (34 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\juan\anaconda3\lib\site-packages (from sympy->torch<2.1,>=1.13->OpenNMT-py) (1.2.1)
# Installing collected packages: typing-extensions, pydantic-core, colorama, catalogue, annotated-types, srsly, pydantic, oauthlib, murmurhash, cymem, wasabi, typer, smart-open, requests-oauthlib, preshed, google-auth, confection, blis, thinc, tensorboard-data-server, spacy-loggers, spacy-legacy, pybind11, protobuf, portalocker, pathy, langcodes, grpcio, google-auth-oauthlib, absl-py, waitress, torch, tensorboard, spacy, sacrebleu, rapidfuzz, pyonmttok, pyahocorasick, fasttext-wheel, ctranslate2, configargparse, OpenNMT-py
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.4
#     Uninstalling colorama-0.4.4:
#       Successfully uninstalled colorama-0.4.4
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.1.0
#     Uninstalling smart-open-5.1.0:
#       Successfully uninstalled smart-open-5.1.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.33.0
#     Uninstalling google-auth-1.33.0:
#       Successfully uninstalled google-auth-1.33.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.1
#     Uninstalling protobuf-3.19.1:
#       Successfully uninstalled protobuf-3.19.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
# Successfully installed OpenNMT-py-3.4 absl-py-1.4.0 annotated-types-0.5.0 blis-0.7.10 catalogue-2.0.9 colorama-0.4.6 confection-0.1.3 configargparse-1.7 ctranslate2-3.19.0 cymem-2.0.8 fasttext-wheel-0.9.2 google-auth-2.23.0 google-auth-oauthlib-1.0.0 grpcio-1.58.0 langcodes-3.3.0 murmurhash-1.0.10 oauthlib-3.2.2 pathy-0.10.2 portalocker-2.8.2 preshed-3.0.9 protobuf-4.24.3 pyahocorasick-2.0.0 pybind11-2.11.1 pydantic-2.3.0 pydantic-core-2.6.3 pyonmttok-1.37.1 rapidfuzz-3.3.0 requests-oauthlib-1.3.1 sacrebleu-2.3.1 smart-open-6.4.0 spacy-3.6.1 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.7 tensorboard-2.14.0 tensorboard-data-server-0.7.1 thinc-8.1.12 torch-2.0.1 typer-0.9.0 typing-extensions-4.7.1 waitress-2.1.2 wasabi-1.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-storage 1.31.0 requires google-auth<2.0dev,>=1.11.0, but you have google-auth 2.23.0 which is incompatible.
# google-cloud-core 1.7.1 requires google-auth<2.0dev,>=1.24.0, but you have google-auth 2.23.0 which is incompatible.
# google-api-core 1.25.1 requires google-auth<2.0dev,>=1.21.1, but you have google-auth 2.23.0 which is incompatible.

# %%
config = '''# config.yaml


## Where the samples will be written
save_data: run

# Training files
data:
    corpus_1:
        path_src: UN.en-fr.fr-filtered.fr.subword.train
        path_tgt: UN.en-fr.en-filtered.en.subword.train
        transforms: [filtertoolong]
    valid:
        path_src: UN.en-fr.fr-filtered.fr.subword.dev
        path_tgt: UN.en-fr.en-filtered.en.subword.dev
        transforms: [filtertoolong]

# Vocabulary files, generated by onmt_build_vocab
src_vocab: run/source.vocab
tgt_vocab: run/target.vocab

# Vocabulary size - should be the same as in sentence piece
src_vocab_size: 50000
tgt_vocab_size: 50000

# Filter out source/target longer than n if [filtertoolong] enabled
src_seq_length: 150
src_seq_length: 150

# Tokenization options
src_subword_model: source.model
tgt_subword_model: target.model

# Where to save the log file and the output models/checkpoints
log_file: train.log
save_model: models/model.fren

# Stop training if it does not imporve after n validations
early_stopping: 4

# Default: 5000 - Save a model checkpoint for each n
save_checkpoint_steps: 1000

# To save space, limit checkpoints to last n
# keep_checkpoint: 3

seed: 3435

# Default: 100000 - Train the model to max n steps 
# Increase to 200000 or more for large datasets
# For fine-tuning, add up the required steps to the original steps
train_steps: 3000

# Default: 10000 - Run validation after n steps
valid_steps: 1000

# Default: 4000 - for large datasets, try up to 8000
warmup_steps: 1000
report_every: 100

# Number of GPUs, and IDs of GPUs
world_size: 1
gpu_ranks: [0]

# Batching
bucket_size: 262144
num_workers: 0  # Default: 2, set to 0 when RAM out of memory
batch_type: "tokens"
batch_size: 4096   # Tokens per batch, change when CUDA out of memory
valid_batch_size: 2048
max_generator_batches: 2
accum_count: [4]
accum_steps: [0]

# Optimization
model_dtype: "fp16"
optim: "adam"
learning_rate: 2
# warmup_steps: 8000
decay_method: "noam"
adam_beta2: 0.998
max_grad_norm: 0
label_smoothing: 0.1
param_init: 0
param_init_glorot: true
normalization: "tokens"

# Model
encoder_type: transformer
decoder_type: transformer
position_encoding: true
enc_layers: 6
dec_layers: 6
heads: 8
hidden_size: 512
word_vec_size: 512
transformer_ff: 2048
dropout_steps: [0]
dropout: [0.1]
attention_dropout: [0.1]
'''

with open("config.yaml", "w+") as config_yaml:
  config_yaml.write(config)

# %%
# !onmt_build_vocab -config config.yaml -n_sample -1 -num_threads 2
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Juan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Juan\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Juan\anaconda3\Scripts\onmt_build_vocab.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Juan\anaconda3\lib\site-packages\onmt\bin\build_vocab.py", line 283, in main
#     build_vocab_main(opts)
#   File "C:\Users\Juan\anaconda3\lib\site-packages\onmt\bin\build_vocab.py", line 213, in build_vocab_main
#     ArgumentParser.validate_prepare_opts(opts, build_vocab_only=True)
#   File "C:\Users\Juan\anaconda3\lib\site-packages\onmt\utils\parse.py", line 195, in validate_prepare_opts
#     cls._validate_data(opt)
#   File "C:\Users\Juan\anaconda3\lib\site-packages\onmt\utils\parse.py", line 60, in _validate_data
#     cls._validate_file(path_src, info=f"{cname}/path_src")
#   File "C:\Users\Juan\anaconda3\lib\site-packages\onmt\utils\parse.py", line 18, in _validate_file
#     raise IOError(f"Please check path of your {info} file!")
# OSError: Please check path of your corpus_1/path_src file!

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce GTX 1060 6GB (UUID: GPU-c370198f-7445-34aa-eeaa-3395e05d6a82)

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# Requirement already satisfied: torch in c:\users\juan\anaconda3\lib\site-packages (2.0.1)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu117/torchvision-0.15.2%2Bcu117-cp39-cp39-win_amd64.whl (4.9 MB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu117/torchaudio-2.0.2%2Bcu117-cp39-cp39-win_amd64.whl (2.5 MB)
# Requirement already satisfied: typing-extensions in c:\users\juan\anaconda3\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: filelock in c:\users\juan\anaconda3\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: sympy in c:\users\juan\anaconda3\lib\site-packages (from torch) (1.10.1)
# Requirement already satisfied: networkx in c:\users\juan\anaconda3\lib\site-packages (from torch) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\juan\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\juan\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: numpy in c:\users\juan\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in c:\users\juan\anaconda3\lib\site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\juan\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\juan\anaconda3\lib\site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\juan\anaconda3\lib\site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\juan\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juan\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\juan\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Installing collected packages: torchvision, torchaudio
# Successfully installed torchaudio-2.0.2+cu117 torchvision-0.15.2+cu117

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False
